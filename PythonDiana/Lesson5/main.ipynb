# %%
import pandas as pd

# %%
df = pd.read_csv("movie_ratings.csv")

# %%
df.head(10)
# Out:
#    Movie_ID     Title   Genre  Rating
# 0         1   Movie_1  Action     3.2
# 1         2   Movie_2  Horror     3.4
# 2         3   Movie_3  Comedy     1.5
# 3         4   Movie_4   Drama     2.5
# 4         5   Movie_5  Comedy     2.1
# 5         6   Movie_6  Comedy     2.7
# 6         7   Movie_7  Action     4.7
# 7         8   Movie_8  Horror     3.0
# 8         9   Movie_9  Action     3.7
# 9        10  Movie_10   Drama     4.8

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Movie_ID  500 non-null    int64
#  1   Title     500 non-null    str
#  2   Genre     500 non-null    str
#  3   Rating    500 non-null    float64
# dtypes: float64(1), int64(1), str(2)
# memory usage: 15.8 KB

# %%
df.shape
# Out:
# (500, 4)

# %%
df.describe()
# Out:
#          Movie_ID      Rating
# count  500.000000  500.000000
# mean   250.500000    3.041000
# std    144.481833    1.169065
# min      1.000000    1.000000
# 25%    125.750000    2.000000
# 50%    250.500000    3.100000
# 75%    375.250000    4.100000
# max    500.000000    5.000000

# %%
df["Genre"]
# Out:
# 0      Action
# 1      Horror
# 2      Comedy
# 3       Drama
# 4      Comedy
#         ...
# 495    Comedy
# 496    Horror
# 497    Comedy
# 498     Drama
# 499     Drama
# Name: Genre, Length: 500, dtype: str

# %%
df[ df["Rating"] > 4.8 ]
# Out:
# 19

# %%
mask_hr = df["Rating"] > 4.0
mask_comedy = df["Genre"] == "Comedy"

mask = mask_hr & mask_comedy
df[mask]
# Out:
#      Movie_ID      Title   Genre  Rating
# 2           3    Movie_3  Comedy     1.5
# 4           5    Movie_5  Comedy     2.1
# 5           6    Movie_6  Comedy     2.7
# 6           7    Movie_7  Action     4.7
# 9          10   Movie_10   Drama     4.8
# ..        ...        ...     ...     ...
# 493       494  Movie_494  Horror     4.5
# 494       495  Movie_495  Action     4.3
# 495       496  Movie_496  Comedy     2.8
# 497       498  Movie_498  Comedy     1.7
# 498       499  Movie_499   Drama     5.0
#
# [187 rows x 4 columns]

# %%
df["Genre"].unique()
# Out:
# <StringArray>
# ['Action', 'Horror', 'Comedy', 'Drama']
# Length: 4, dtype: str

# %%
df.groupby("Genre")["Rating"].mean()
# Out:
# Genre
# Action    3.169504
# Comedy    3.082540
# Drama     3.002632
# Horror    2.881513
# Name: Rating, dtype: float64

# %%
df.groupby("Genre")["Rating"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='Genre'>

# %%
df.iat[0, 3] = 6.0
df.iat[1, 3] = 6.0
df.iat[2, 3] = 6.0
df.iat[3, 3] = 6.0
df.iat[4, 3] = 6.0
df.iat[5, 3] = 6.0
df.iat[6, 3] = 6.0
df.iat[7, 3] = 6.0
df.iat[8, 3] = 6.0
df.iat[9, 3] = 6.0
df.iat[10, 3] = 6.0
df.iat[11, 3] = 6.0
df
# Out:
#      Movie_ID      Title   Genre  Rating
# 0           1    Movie_1  Action     6.0
# 1           2    Movie_2  Horror     6.0
# 2           3    Movie_3  Comedy     6.0
# 3           4    Movie_4   Drama     6.0
# 4           5    Movie_5  Comedy     6.0
# ..        ...        ...     ...     ...
# 495       496  Movie_496  Comedy     2.8
# 496       497  Movie_497  Horror     3.1
# 497       498  Movie_498  Comedy     1.7
# 498       499  Movie_499   Drama     5.0
# 499       500  Movie_500   Drama     2.9
#
# [500 rows x 4 columns]

# %%
df["Rating"].plot(kind="box")
# Out:
# <Axes: >
